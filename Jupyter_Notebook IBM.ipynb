# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Peer Graded Assignment

# %% [markdown]
# This is a test assignment for Data Science Tools Training

# %% [markdown]
# _This is a list of Data science languages_
# - Python
# - R
# - SQL
# - Java
# - Julia
# - Scala
# - JavaScript

# %% [markdown]
# _This is a list of Data science libraries_
# - Pytorch
# - Tensorflow
# - Theano
# - Pandas
# - Tidyverse
# - NumPy
# - Keras

# %% [markdown]
# _This is a list of Data science tools_
# - RStudio IDE
# - Jupiter Notebooks
# - Github
# - SAS
# - Excel
# - Tabluea
# - Apache Spark

# %% [markdown]
# _These are examples of Arithemtic expressions_

# %%
2 + 3
# Out:
# 5

# %%
5 * 77
# Out:
# 385

# %% [markdown]
# _convert minutes to hours_

# %%
120/60
# Out:
# 2.0

# %% [markdown]
# _Objectives_
# - To learn how to use Jupiter Notebook
# - To complete this assignment

# %% [markdown]
# _Author name_
#
# __Ahuba Oscar__
